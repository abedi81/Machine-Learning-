# %%
import numpy as np
np.random.seed(0)
x = np.random.normal(size=10)
x.mean(), x.std()
# Out:
# (0.7380231707288347, 0.9670792110785361)

# %%
y = 2*x + np.random.normal(scale=0.5, size=len(x))
np.corrcoef(x, y)[0, 1]
# Out:
# 0.9392359123825418
